# %%
#Landsat NDVI vs THERMAL

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke11.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke11.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke1_1_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 1_1")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.38074167181302143
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\443823738.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke12.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke12.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke1_2_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 1_2")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.05991868681534224
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\638091765.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke13.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke13.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke1_3_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 1_3")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.4508809642590085
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\2284504988.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke14.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke14.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke1_4_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 1_4")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.10465137900788418
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\1534986278.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke21.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke21.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke2_1_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 2_1")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: 0.09727701097199809
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\2093363936.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke22.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke22.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke2_2_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 2_2")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.3148799887386605
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\2489835733.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke23.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke23.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke2_3_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 2_3")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.01830063846700581
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\3051311529.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke24.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke24.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke2_4_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 2_4")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: 0.22802865075560363
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\3297090257.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke25.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke25.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke2_5_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 2_5")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.4682014248252333
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\4200884918.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke26.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke26.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke2_6_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 2_6")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.1840225368296321
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\51434297.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke27.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke27.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke2_7_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 2_7")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.17869508202741413
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\1135359746.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke28.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke28.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke2_8_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 2_8")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.012172499828397881
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\678610968.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke29.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke29.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke2_9_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 2_9")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: 0.04643016913863567
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\2950806176.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke31.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke31.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke3_1_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 3_1")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.1995176394119305
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\587041987.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke32.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke32.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke3_2_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 3_2")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: 0.08667528787469242
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\1098702705.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke33.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke33.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke3_3_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 3_3")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.4790427330305125
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\1649248788.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke34.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke34.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke3_4_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 3_4")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.2951009919719604
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\3169588270.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke35.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke35.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke3_5_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 3_5")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.15601343007451243
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\994545769.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the red band and NIR band rasters
with rasterio.open(r'/Landsat9/L9_B5_Soke36.tif') as nir_ras:
    nir = nir_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B4_Soke36.tif') as red_ras:
    red = red_ras.read(1)

# Calculate NDVI
NDVI = (nir - red) / (nir + red)

# Open the raster dataset
with rasterio.open(r'/Landsat9_thermal/Soke3_6_T.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)

# Extract the plant heights from the raster values
thermal = raster_values[raster_values > 0]

# Resize the NDVI array to have the same dimensions as thermal
NDVI_resized = np.resize(NDVI, thermal.shape)

# Remove NaN values from the arrays
valid_indices = np.logical_not(np.logical_or(np.isnan(thermal), np.isnan(NDVI_resized)))
thermal = thermal[valid_indices]
NDVI_resized = NDVI_resized[valid_indices]

# Calculate the Pearson correlation coefficient
correlation, _ = pearsonr(thermal, NDVI_resized)

# Print the Pearson correlation
print("Correlation:", correlation)

# Create a scatter plot
plt.scatter(thermal, NDVI_resized)
plt.xlabel("Thermal of Landsat")
plt.ylabel("NDVI Values")
plt.title("Scatter Plot of Thermal Band and NDVI 3_6")

# Add the Pearson correlation line
z = np.polyfit(thermal, NDVI_resized, 1)
p = np.poly1d(z)
plt.plot(thermal, p(thermal), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# Correlation: -0.2644185143360547
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_6268\188190907.py:13: RuntimeWarning: invalid value encountered in divide
#   NDVI = (nir - red) / (nir + red)
