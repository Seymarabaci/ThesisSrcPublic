# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_11.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_11.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_11.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_11.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 1_1")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\3032801977.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: -0.011093666005717944

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_12.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_12.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_12.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_12.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 1_2")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\1941766359.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: -0.015101668188827726

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_13.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_13.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_13.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_13.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 1_3")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\2770491870.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.01801147332926114

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_14.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_14.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_14.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_14.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 1_4")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\2328251692.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: -0.14542729924547732

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_21.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_21.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_21.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_21.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 2_1")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\2471379575.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.032251869029443596

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_22.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_22.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_22.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_22.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 2_2")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\3422363261.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.013445895416322545

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_23.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_23.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_23.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_23.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 2_3")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\2822204857.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.07354231035775612

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_24.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_24.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_24.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_24.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 2_4")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\3181034980.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.017874884727037278

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_25.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_25.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_25.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_25.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 2_5")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\3186021168.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.014074552599419695

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_26.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_26.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_26.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_26.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 2_6")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\2211282337.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.013801726733029367

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_27.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_27.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_27.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_27.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 2_7")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\2451481743.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: -0.01665002569966735

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_28.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_28.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_28.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_28.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 2_8")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\2165893657.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: -0.00783206203017708

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_29.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_29.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_29.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_29.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 2_9")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\3030773798.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.03612690935925219

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_31.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_31.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_31.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_31.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 3_1")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\1856039059.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: -0.019039835885784392

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_32.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_32.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_32.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_32.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 3_2")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\590304010.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.006277218071160776

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_33.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_33.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_33.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_33.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 3_3")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\442622432.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: 0.008864251886464869

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_34.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_34.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_34.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_34.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 3_4")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\2995534024.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: -0.001588861633007975

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_35.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_35.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_35.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_35.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 3_5")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\3723359172.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: -0.0062731237581026885

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Open the raster datasets
with rasterio.open(r'/Resampled/repro_thermal_36.tif') as src1:
    # Read the raster values into a numpy array
    raster_values1 = src1.read(1)
thermal = raster_values1[raster_values1 > 0]

with rasterio.open(r'/Resampled/repro_wide_36.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Resampled/repro_wide_36.tif') as green_ras:
    green = green_ras.read(2)
with rasterio.open(r'/Resampled/repro_wide_36.tif') as blue_ras:
    blue = blue_ras.read(3)
TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)

values1 = TGI.flatten()
values2 = thermal.flatten()

# Find common valid indices
valid_indices = np.intersect1d(np.where(~np.isnan(values1))[0], np.where(~np.isnan(values2))[0])
values1 = values1[valid_indices]
values2 = values2[valid_indices]

# Calculate the Pearson correlation between the two arrays
correlation = np.corrcoef(values1, values2)[0, 1]

# Print the Pearson correlation
print("correlation:", correlation)

# Create a scatter plot
plt.scatter(values1, values2)
plt.xlabel("TGI Values")
plt.ylabel("Thermal Values")
plt.title("Scatter Plot of TGI and Thermal 3_6")

# Add the Pearson correlation line
z = np.polyfit(values1, values2, 1)
p = np.poly1d(z)
plt.plot(values1, p(values1), color='red')

# Add the Pearson correlation line
plt.annotate(f"Pearson correlation: {correlation:.2f}", xy=(0.6, 0.1), xycoords='axes fraction', color='red')

# Show the plot
plt.show()
# Out:
# C:\Users\Seyma\AppData\Local\Temp\ipykernel_17136\484688428.py:17: RuntimeWarning: invalid value encountered in divide
#   TGI = (green - (blue + red) / 2) / np.sqrt(green + (blue + red) / 2)
# correlation: -0.018496458478951823
