# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/Resampled/repro_DEM_11_mask.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
#plant_heights = raster_values[raster_values > 0]

# Create a histogram

plt.hist(plant_heights, bins = 100)

# Add a title and labels
plt.title("Plant Heights in 1_1")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 12.113401412963867
# Maximum value: 16.697555541992188
# Average canopy height: 13.255597114562988 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke12_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values

# Create a histogram

plt.hist(plant_heights, bins = 50)

# Add a title and labels
plt.title("Plant Heights in 1_2")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 12.113401412963867
# Maximum value: 16.697555541992188
# Average canopy height: 13.255597114562988 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke13_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 1_3")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 11.590126991271973
# Maximum value: 13.8626127243042
# Average canopy height: 13.028755187988281 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke14_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 1_4")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 11.848821640014648
# Maximum value: 14.206056594848633
# Average canopy height: 13.464971542358398 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke21_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 2_1")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.308956146240234
# Maximum value: 40.67067337036133
# Average canopy height: 32.35169982910156 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke22_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 2_2")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.46919822692871
# Maximum value: 33.05384063720703
# Average canopy height: 32.45331954956055 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke23_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 2_3")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.519760131835938
# Maximum value: 33.36678695678711
# Average canopy height: 32.447357177734375 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke24_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 2_4")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.588294982910156
# Maximum value: 32.945106506347656
# Average canopy height: 32.258235931396484 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke25_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 2_5")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.748004913330078
# Maximum value: 33.097564697265625
# Average canopy height: 32.51520538330078 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke26_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 2_6")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.766576766967773
# Maximum value: 33.218563079833984
# Average canopy height: 32.51004409790039 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke27_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 2_7")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.830995559692383
# Maximum value: 33.1837158203125
# Average canopy height: 32.587337493896484 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke28_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 2_8")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.914392471313477
# Maximum value: 33.64119338989258
# Average canopy height: 32.62176513671875 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke29_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 2_9")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.99029541015625
# Maximum value: 33.60258483886719
# Average canopy height: 32.74665069580078 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke31_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 3_1")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 32.02745056152344
# Maximum value: 33.57192611694336
# Average canopy height: 32.632476806640625 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke32_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 3_2")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.776945114135742
# Maximum value: 33.24479675292969
# Average canopy height: 32.384376525878906 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke33_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 3_3")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.893957138061523
# Maximum value: 33.15046691894531
# Average canopy height: 32.442161560058594 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke34_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 3_4")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.784095764160156
# Maximum value: 33.4869499206543
# Average canopy height: 32.33403015136719 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke35_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 3_5")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.7425594329834
# Maximum value: 33.08256912231445
# Average canopy height: 32.324893951416016 cm

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Open the raster dataset
with rasterio.open(r'/DEM/Soke36_DEM.tif') as src:
    # Read the raster values into a numpy array
    raster_values = src.read(1)
    
# Extract the plant heights from the raster values
plant_heights = raster_values[raster_values > 0]

# Create a histogram
hist_range = (10, 35)
plt.hist(plant_heights, bins = 50, range=hist_range)

# Add a title and labels
plt.title("Plant Heights in 3_6")
plt.xlabel("Height (cm)")
plt.ylabel("Number of Pixels")

# Show the plot
plt.show()
cotton_height = np.mean(plant_heights)
min_val = plant_heights.min()
max_val = plant_heights.max()

print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Average canopy height: {cotton_height} cm")
# Out:
# Minimum value: 31.64801788330078
# Maximum value: 33.42245864868164
# Average canopy height: 32.410011291503906 cm
