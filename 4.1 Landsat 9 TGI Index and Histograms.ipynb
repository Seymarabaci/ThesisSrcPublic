# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np 
# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke11.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke11.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke11.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue

TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)


# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 1_1', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke12.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke12.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke12.tif') as blue_ras:
    blue = blue_ras.read(1)

 # Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 1_2', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt

# Load the red band and NIR band rasters
# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke13.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke13.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke13.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 1_3', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke14.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke14.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke14.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 1_4', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke21.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke21.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke21.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 2_1', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke22.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke22.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke22.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 2_2', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke23.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke23.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke23.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 2_3', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke24.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke24.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke24.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 2_4', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke25.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke25.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke25.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 2_5', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke26.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke26.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke26.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 2_6', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke27.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke27.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke27.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 2_7', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke28.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke28.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke28.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 2_8', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke29.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke29.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke29.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 2_9', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke31.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke31.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke31.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 3_1', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke32.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke32.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke32.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 3_2', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke33.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke33.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke33.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 3_3', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke34.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke34.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke34.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 3_4', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke35.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke35.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke35.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 3_5', 
          histtype='stepfilled', alpha=0.7)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the red band and green and blue band rasters
with rasterio.open(r'/Landsat9/L9_B4_Soke36.tif') as red_ras:
    red = red_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B3_Soke36.tif') as green_ras:
    green = green_ras.read(1)
with rasterio.open(r'/Landsat9/L9_B2_Soke36.tif') as blue_ras:
    blue = blue_ras.read(1)

# Calculate TGI
TGI = green-0.39*red-0.61*blue
TGI_filtered = np.where(TGI<0.000001,np.nan,TGI)

# Create a figure and plot the TGI image using the "RdYlGn" color map
fig, ax = plt.subplots()
im = ax.imshow(TGI_filtered, cmap="RdYlGn")

# Add a color bar to the figure
cbar = fig.colorbar(im, ax=ax)

# Show the figure
plt.show()
from rasterio.plot import show_hist
show_hist(source=TGI_filtered, bins=50, title='Histogram of TGI 3_6', 
          histtype='stepfilled', alpha=0.7)
